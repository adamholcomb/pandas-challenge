# %%
# Pandas Dependencies and Setup
import pandas as pd

# Load File
csvfile = "Resources/purchase_data.csv"

# Read file and store into data frame
purchase_data = pd.read_csv(csvfile)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Determine total number of players
player_count = len(purchase_data["SN"].unique())
total_players = pd.DataFrame({"Total Players": [player_count]})
total_players
# Out:
#    Total Players
# 0            576

# %%
# Determine totals: unique items, avg purchase price, number of purchases, revenue
unique_items = len(purchase_data["Item Name"].unique())
avg_purchase = purchase_data["Price"].mean()
total_purchases = len(purchase_data["Purchase ID"])
total_revenue = purchase_data["Price"].sum()

# Put data into DataFrame
total_df = pd.DataFrame({"Unique Items":[unique_items],"Average Purchase Price":[avg_purchase],"Number of Purchases":[total_purchases],"Total Revenue":[total_revenue]})

# Map formatting onto average purchase and total revenue
total_df["Average Purchase Price"] = total_df["Average Purchase Price"].map("${:.2f}".format)
total_df["Total Revenue"] = total_df["Total Revenue"].map("${:,.2f}".format)
total_df
# Out:
#    Unique Items Average Purchase Price  Number of Purchases Total Revenue
# 0           179                  $3.05                  780     $2,379.77

# %%
# Gender Demographics

# Count of male, female, and other/non-disclosed players
unique_players = purchase_data.drop_duplicates(["SN"])
gender_data = unique_players.groupby(["Gender"]).count()

# ** I did not end up using this because I felt like this was not the cleanest method and changed directions**
dudes = gender_data.loc["Male","SN"]
dudettes = gender_data.loc["Female","SN"]
other = gender_data.loc["Other / Non-Disclosed","SN"]

# %%
# Gender Demographics

# Percentage of each gender
# **Did not end up using this because I felt like this was not the cleanest method and changed directions**
dude_percent = (dudes/player_count*100)
dudette_percent = (dudettes/player_count*100)
other_percent = (other/player_count*100)

# Construct gender demographics DataFrame and percentage using DataFrames
gender_df = pd.DataFrame(gender_data["SN"])
percentage = gender_df["SN"]/player_count*100
gender_df["Percentage of Players"] = percentage

# Formatting
gender_df["Percentage of Players"] = gender_df["Percentage of Players"].map("{:.2f}%".format)
gender_df.rename(columns={"SN":"Total Count"},inplace=True)
gender_df2 = gender_df.sort_values(by = "Total Count",ascending = False)

gender_df2
# Out:
#                        Total Count Percentage of Players
# Gender
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %%
# Purchasing Analysis (Gender)
# By gender, obtain purchase count, avg purchase price, total purchase value, and avg purchase total per person

# Assemble data
purchase_counts = purchase_data.groupby("Gender")["Purchase ID"].count()
avg_purchase_price = purchase_data.groupby("Gender")["Price"].mean()
purchase_value = purchase_data.groupby("Gender")["Price"].sum()
avg_purchase_pp = purchase_value/(gender_df["Total Count"])

# %%
# Purchasing Analysis (Gender)

# Build DataFrame
purchasing_df = pd.DataFrame({"Purchase Count":purchase_counts,"Avg Purchase Price":avg_purchase_price,"Total Purchase Value":purchase_value,"Avg Purchase Total per Person":avg_purchase_pp})
purchasing_df["Avg Purchase Price"] = purchasing_df["Avg Purchase Price"].map("${:.2f}".format)
purchasing_df["Total Purchase Value"] = purchasing_df["Total Purchase Value"].map("${:,.2f}".format)
purchasing_df["Avg Purchase Total per Person"] = purchasing_df["Avg Purchase Total per Person"].map("${:.2f}".format)


purchasing_df
# Out:
#                        Purchase Count Avg Purchase Price Total Purchase Value  \
# Gender
# Female                            113              $3.20              $361.94
# Male                              652              $3.02            $1,967.64
# Other / Non-Disclosed              15              $3.35               $50.19
#
#                       Avg Purchase Total per Person
# Gender
# Female                                        $4.47
# Male                                          $4.07
# Other / Non-Disclosed                         $4.56

# %%
# Age Demographics
# Break down into 4-year bins: Purchase Count, Avg Purchase Price, Total Purchase Value, avg purchase total per person

# Create bin column
bins = [0,9,14,19,24,29,34,39,99]
bin_names = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']
purchase_data["Age Group"] = pd.cut(purchase_data["Age"],bins,labels=bin_names)

purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
# Age Demographics

# Use groupby to get purchase count, Avg Purchase Price, Total Purchase Value by age group
age_purchase_count = purchase_data.groupby("Age Group")["Purchase ID"].count()
age_avg_price = purchase_data.groupby("Age Group")["Price"].mean()
age_total_value = purchase_data.groupby("Age Group")["Price"].sum()

# Avg purchase total per person by age group
unique_players2 = purchase_data.drop_duplicates(["SN"])
age_avg_purchase = age_total_value/(unique_players2.groupby(["Age Group"])["SN"].count())

# %%
# Age Demographics

# Build DataFrame
age_df = pd.DataFrame({"Purchase Count":age_purchase_count,"Average Purchase Price":age_avg_price,"Total Purchase Value":age_total_value,"Avg Total Purchase per Person":age_avg_purchase})

# Formatting
age_df["Average Purchase Price"] = age_df["Average Purchase Price"].map("${:.2f}".format)
age_df["Total Purchase Value"] = age_df["Total Purchase Value"].map("${:,.2f}".format)
age_df["Avg Total Purchase per Person"] = age_df["Avg Total Purchase per Person"].map("${:,.2f}".format)

age_df
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Group
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#           Avg Total Purchase per Person
# Age Group
# <10                               $4.54
# 10-14                             $3.76
# 15-19                             $3.86
# 20-24                             $4.32
# 25-29                             $3.81
# 30-34                             $4.12
# ...

# %%
# Top Spenders
# ID the top 5 by total purchase value. List their SN, purchase count, avg purchase price, total purchase price

user_spend = purchase_data.groupby("SN")["Price"].sum()
top5 = user_spend.sort_values(ascending=False)
top5.head()
# Out:
# SN
# Lisosia93      18.96
# Idastidru52    15.45
# Chamjask73     13.83
# Iral74         13.62
# Iskadarya95    13.10
# Name: Price, dtype: float64
